# %%
from IPython.display import display, HTML
display(HTML(r'''
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <title>🔒 PoseGuard Elite Documentation Portal</title>
  <style>
    * { margin: 0; padding: 0; box-sizing: border-box; }
    :root { --primary: #667eea; --secondary: #764ba2; --accent: #00d4ff; --dark: #0a0e27; }
    body { 
      font-family: 'Inter', 'Segoe UI', sans-serif; 
      background: linear-gradient(-45deg, #667eea 0%, #764ba2 25%, #00d4ff 50%, #667eea 75%, #764ba2 100%);
      background-size: 400% 400%;
      animation: gradient-shift 15s ease infinite;
      min-height: 100vh; 
      color: #e0e0e0; 
      padding: 0;
      overflow-x: hidden;
      position: relative;
    }
    body::before {
      content: '';
      position: fixed;
      top: 0;
      left: 0;
      width: 100%;
      height: 100%;
      background: radial-gradient(ellipse at 20% 50%, rgba(102, 126, 234, 0.1) 0%, transparent 50%),
                  radial-gradient(ellipse at 80% 80%, rgba(0, 212, 255, 0.1) 0%, transparent 50%);
      pointer-events: none;
      z-index: -1;
    }
    @keyframes gradient-shift { 0% { background-position: 0% 50%; } 50% { background-position: 100% 50%; } 100% { background-position: 0% 50%; } }
    @keyframes float { 0%, 100% { transform: translateY(0) translateX(0); } 50% { transform: translateY(-20px) translateX(5px); } }
    @keyframes glow { 0%, 100% { box-shadow: 0 0 20px rgba(0, 212, 255, 0.3), inset 0 0 20px rgba(102, 126, 234, 0.1); } 50% { box-shadow: 0 0 40px rgba(0, 212, 255, 0.5), inset 0 0 30px rgba(102, 126, 234, 0.2); } }
    @keyframes pulse-ring { 0% { box-shadow: 0 0 0 0 rgba(0, 212, 255, 0.7); } 70% { box-shadow: 0 0 0 20px rgba(0, 212, 255, 0); } 100% { box-shadow: 0 0 0 0 rgba(0, 212, 255, 0); } }
    .container { max-width: 1300px; margin: 0 auto; padding: 30px 20px; }
    .header-section { 
      background: rgba(102, 126, 234, 0.08);
      backdrop-filter: blur(20px);
      -webkit-backdrop-filter: blur(20px);
      border: 1px solid rgba(0, 212, 255, 0.25);
      border-radius: 24px; 
      padding: 100px 60px; 
      text-align: center; 
      position: relative; 
      overflow: hidden; 
      margin-bottom: 50px;
      margin-top: 30px; 
      animation: glow 3s ease-in-out infinite;
    }
    .header-section::before { 
      content: ''; 
      position: absolute; 
      top: -50%; 
      right: -50%; 
      width: 600px; 
      height: 600px; 
      background: radial-gradient(circle, rgba(0, 212, 255, 0.2), transparent); 
      border-radius: 50%; 
      animation: float 20s linear infinite; 
      z-index: 1; 
    }
    .header-section::after { 
      content: ''; 
      position: absolute; 
      bottom: -50%; 
      left: -50%; 
      width: 500px; 
      height: 500px; 
      background: radial-gradient(circle, rgba(102, 126, 234, 0.25), transparent); 
      border-radius: 50%; 
      animation: float 25s linear infinite reverse; 
      z-index: 1; 
    }
    h1 { 
      font-size: 4.5em; 
      margin-bottom: 0.15em; 
      position: relative; 
      z-index: 2; 
      background: linear-gradient(120deg, #667eea 0%, #00d4ff 50%, #764ba2 100%);
      -webkit-background-clip: text; 
      -webkit-text-fill-color: transparent; 
      background-clip: text;
      font-weight: 900; 
      letter-spacing: -3px; 
      text-shadow: 0 0 60px rgba(102, 126, 234, 0.3);
      filter: drop-shadow(0 0 30px rgba(0, 212, 255, 0.2));
    }
    .subtitle { 
      font-size: 1.4em; 
      opacity: 0.9; 
      margin-bottom: 1.5em; 
      position: relative; 
      z-index: 2; 
      color: #00d4ff;
      font-weight: 300;
      letter-spacing: 1px;
    }
    .status-badge { 
      display: inline-block; 
      background: linear-gradient(135deg, #4caf50 0%, #45a049 100%); 
      color: #fff; 
      padding: 14px 32px; 
      border-radius: 50px; 
      font-weight: 800;
      margin-top: 2em; 
      position: relative; 
      z-index: 2; 
      animation: pulse-ring 2.5s ease-out infinite;
      box-shadow: 0 0 30px rgba(76, 175, 80, 0.4);
    }
    nav { 
      background: rgba(10, 14, 39, 0.7); 
      backdrop-filter: blur(20px);
      -webkit-backdrop-filter: blur(20px);
      border-bottom: 1px solid rgba(0, 212, 255, 0.15); 
      padding: 0; 
      position: sticky; 
      top: 0; 
      z-index: 100; 
      box-shadow: 0 8px 32px rgba(0, 0, 0, 0.3);
    }
    nav ul { 
      list-style: none; 
      display: flex; 
      flex-wrap: wrap; 
      padding: 12px 40px; 
      margin: 0; 
      gap: 4px; 
    }
    nav a { 
      color: #00d4ff; 
      text-decoration: none; 
      font-weight: 700;
      font-size: 0.95em; 
      padding: 10px 16px; 
      display: block; 
      transition: all 0.35s cubic-bezier(0.4, 0, 0.2, 1); 
      border-radius: 8px; 
      border: 1px solid transparent;
      position: relative;
    }
    nav a::before {
      content: '';
      position: absolute;
      inset: 0;
      border-radius: 8px;
      background: linear-gradient(135deg, rgba(0, 212, 255, 0.2), rgba(102, 126, 234, 0.2));
      opacity: 0;
      transition: opacity 0.35s ease;
      z-index: -1;
    }
    nav a:hover { 
      color: #fff;
      border-color: #00d4ff; 
      transform: translateY(-3px);
    }
    nav a:hover::before { opacity: 1; }
    .content { 
      padding: 50px; 
      background: rgba(15, 23, 42, 0.5); 
      backdrop-filter: blur(10px);
      -webkit-backdrop-filter: blur(10px);
      border-radius: 16px; 
      margin-bottom: 50px;
      border: 1px solid rgba(255, 255, 255, 0.05);
    }
    h2 { 
      color: #00d4ff; 
      font-size: 2.5em; 
      margin: 2.5em 0 1.2em 0; 
      position: relative; 
      padding-bottom: 0.7em; 
      font-weight: 800;
      text-transform: uppercase;
      letter-spacing: 2px;
    }
    h2::before { 
      content: ''; 
      position: absolute; 
      bottom: -8px; 
      left: 0; 
      width: 0;
      height: 6px; 
      background: linear-gradient(90deg, #667eea, #00d4ff, #764ba2); 
      border-radius: 3px; 
      box-shadow: 0 0 20px rgba(0, 212, 255, 0.6);
      animation: line-expand 0.8s ease forwards;
    }
    @keyframes line-expand { to { width: 120px; } }
    h3 { 
      color: #00d4ff; 
      font-size: 1.5em; 
      margin: 2em 0 0.8em 0; 
      font-weight: 700;
      text-transform: uppercase; 
      letter-spacing: 1.5px;
    }
    .lead { 
      font-weight: 800; 
      color: #00d4ff;
      text-transform: uppercase;
    }
    .section { margin-top: 2.5em; }
    .collapsible { 
      background: rgba(102, 126, 234, 0.1); 
      backdrop-filter: blur(15px);
      -webkit-backdrop-filter: blur(15px);
      border: 1px solid rgba(0, 212, 255, 0.2); 
      border-radius: 16px; 
      margin: 2em 0; 
      overflow: hidden; 
      transition: all 0.4s cubic-bezier(0.4, 0, 0.2, 1); 
      position: relative;
    }
    .collapsible::before {
      content: '';
      position: absolute;
      top: 0;
      left: 0;
      right: 0;
      height: 1px;
      background: linear-gradient(90deg, transparent, #00d4ff, transparent);
      z-index: 10;
    }
    .collapsible:hover { 
      border-color: rgba(0, 212, 255, 0.4); 
      box-shadow: 0 8px 40px rgba(0, 212, 255, 0.15);
      transform: translateY(-2px);
    }
    .collapsible-header { 
      cursor: pointer; 
      padding: 22px 28px; 
      font-size: 1.25em; 
      font-weight: 800;
      color: #00d4ff; 
      display: flex; 
      align-items: center; 
      background: linear-gradient(90deg, rgba(102, 126, 234, 0.15), transparent); 
      transition: all 0.35s ease; 
      position: relative; 
      z-index: 2;
      text-transform: uppercase;
      letter-spacing: 1px;
    }
    .collapsible-header:hover { 
      background: linear-gradient(90deg, rgba(0, 212, 255, 0.2), transparent);
      padding-left: 32px;
    }
    .collapsible-header:after { 
      content: ''; 
      margin-left: auto; 
      width: 24px; 
      height: 24px; 
      border-right: 3px solid #00d4ff; 
      border-bottom: 3px solid #00d4ff; 
      transform: rotate(-45deg) translateY(-2px); 
      transition: transform 0.4s cubic-bezier(0.4, 0, 0.2, 1); 
    }
    .collapsible.active .collapsible-header:after { 
      transform: rotate(135deg) translateY(2px); 
    }
    .collapsible-content { 
      display: none; 
      padding: 0 28px 28px 28px; 
      background: rgba(10, 14, 39, 0.5); 
      color: #e0e0e0;
      border-top: 1px solid rgba(0, 212, 255, 0.1);
    }
    .collapsible.active .collapsible-content { 
      display: block; 
      animation: slideDown 0.5s cubic-bezier(0.4, 0, 0.2, 1); 
    }
    @keyframes slideDown { 
      from { 
        opacity: 0; 
        transform: translateY(-20px); 
        max-height: 0; 
      } 
      to { 
        opacity: 1; 
        transform: translateY(0); 
        max-height: 3000px; 
      } 
    }
    table { 
      width: 100%; 
      margin: 2em 0; 
      border-collapse: separate; 
      border-spacing: 0; 
      border-radius: 12px; 
      overflow: hidden; 
      box-shadow: 0 8px 32px rgba(0, 0, 0, 0.3);
    }
    th { 
      background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); 
      color: #fff; 
      font-weight: 800; 
      padding: 16px 18px; 
      text-align: left;
      text-transform: uppercase;
      letter-spacing: 1px;
      font-size: 0.9em;
    }
    td { 
      padding: 14px 18px; 
      border-bottom: 1px solid rgba(255, 255, 255, 0.05); 
      background: rgba(20, 30, 60, 0.4);
      transition: all 0.3s ease;
    }
    tr:hover td { 
      background: rgba(102, 126, 234, 0.2);
      border-bottom-color: rgba(0, 212, 255, 0.2);
    }
    tr:last-child td { border-bottom: none; }
    .diagram { 
      font-family: 'Courier New', monospace; 
      background: linear-gradient(135deg, rgba(102, 126, 234, 0.15), rgba(0, 212, 255, 0.1));
      padding: 28px; 
      border-radius: 12px; 
      margin: 2em 0; 
      border: 1px solid rgba(0, 212, 255, 0.2);
      line-height: 1.8; 
      overflow-x: auto; 
      color: #00d4ff;
      box-shadow: inset 0 0 30px rgba(0, 212, 255, 0.05);
    }
    .timeline { 
      border-left: 4px solid; 
      border-image: linear-gradient(to bottom, #667eea, #764ba2, #00d4ff) 1; 
      margin: 2.5em 0 0 0; 
      padding-left: 2.5em; 
    }
    .timeline-entry { 
      margin-bottom: 2.5em; 
      padding-bottom: 2.5em; 
      border-bottom: 1px solid rgba(102, 126, 234, 0.2); 
      position: relative;
    }
    .timeline-entry::before { 
      content: ''; 
      position: absolute; 
      left: -3.5em; 
      top: 0; 
      width: 20px; 
      height: 20px; 
      background: linear-gradient(135deg, #667eea, #00d4ff); 
      border-radius: 50%; 
      box-shadow: 0 0 0 4px rgba(10, 14, 39, 0.8), 0 0 25px rgba(0, 212, 255, 0.6);
      transition: all 0.3s ease;
    }
    .timeline-entry:hover::before {
      transform: scale(1.3);
      box-shadow: 0 0 0 6px rgba(10, 14, 39, 0.8), 0 0 40px rgba(0, 212, 255, 0.8);
    }
    .timeline-entry:last-child { border-bottom: none; }
    .timeline-date { 
      font-weight: 900; 
      color: #00d4ff; 
      font-size: 1.25em;
      text-transform: uppercase;
      letter-spacing: 1px;
    }
    .assumption { 
      background: linear-gradient(135deg, rgba(255, 193, 7, 0.1), rgba(255, 193, 7, 0.05)); 
      border-left: 4px solid #ffc107; 
      padding: 18px 24px; 
      border-radius: 8px; 
      margin: 1.5em 0; 
      color: #ffd54f;
      backdrop-filter: blur(10px);
    }
    .toc-list { 
      columns: 2; 
      -webkit-columns: 2; 
      -moz-columns: 2;
    }
    .toc-list li { 
      margin-bottom: 1em;
    }
    .toc-list a { 
      color: #00d4ff; 
      text-decoration: none; 
      transition: all 0.3s ease;
      font-weight: 600;
      position: relative;
    }
    .toc-list a::before {
      content: '';
      position: absolute;
      bottom: -2px;
      left: 0;
      width: 0;
      height: 2px;
      background: linear-gradient(90deg, #00d4ff, transparent);
      transition: width 0.3s ease;
    }
    .toc-list a:hover::before { width: 100%; }
    code { 
      background: rgba(0, 0, 0, 0.4); 
      padding: 4px 10px; 
      border-radius: 5px; 
      font-family: 'Courier New', monospace; 
      color: #00d4ff; 
      border: 1px solid rgba(0, 212, 255, 0.3);
      font-weight: 600;
    }
    ul { margin: 0.8em 0 1.2em 2.5em; }
    ul li { margin-bottom: 0.7em; line-height: 1.8; }
    ol { margin: 0.8em 0 1.2em 2.5em; }
    ol li { margin-bottom: 0.7em; line-height: 1.8; }
    b { color: #00d4ff; font-weight: 700; }
    @media (max-width: 800px) { 
      .container { padding: 16px; } 
      .content { padding: 24px; } 
      .header-section { padding: 50px 24px; } 
      h1 { font-size: 2.5em; } 
      h2 { font-size: 1.6em; } 
      nav ul { padding: 12px 20px; flex-direction: column; } 
    }
  </style>
  <script>
    document.addEventListener('DOMContentLoaded', function() {
      // Collapsible functionality
      document.querySelectorAll('.collapsible-header').forEach(function(header) {
        header.addEventListener('click', function() {
          var parent = header.parentElement;
          parent.classList.toggle('active');
        });
      });
      
      // Smooth scroll navigation
      document.querySelectorAll('nav a[href^="#"]').forEach(anchor => {
        anchor.addEventListener('click', function(e) {
          e.preventDefault();
          const target = document.querySelector(this.getAttribute('href'));
          if (target) {
            target.scrollIntoView({ behavior: 'smooth', block: 'start' });
          }
        });
      });
    });
  </script>
</head>
<body>
  <div class="container">
    <div class="header-section">
      <h1>🔒 PoseGuard Elite</h1>
      <p class="subtitle">Security Monitoring Architecture<br><span style="font-size: 0.85em; color: #667eea; font-weight: 600;">Complete Development & Technical Portal</span></p>
      <div class="status-badge">✓ PRODUCTION READY</div>
    </div>
    
    <nav>
      <ul>
        <li><a href="#toc">📋 TOC</a></li>
        <li><a href="#file-analysis">📁 FILES</a></li>
        <li><a href="#architecture">🏗️ ARCH</a></li>
        <li><a href="#development-journey">📈 JOURNEY</a></li>
        <li><a href="#features">⚙️ FEATURES</a></li>
        <li><a href="#best-practices">💡 BEST</a></li>
        <li><a href="#timeline">⏱️ TIMELINE</a></li>
      </ul>
    </nav>
    
    <div class="content">
      <div class="section" id="toc">
        <h2>📋 CONTENTS</h2>
        <ul class="toc-list">
          <li><a href="#file-analysis">File Analysis & Dependencies</a></li>
          <li><a href="#architecture">Architecture & Workflow</a></li>
          <li><a href="#development-journey">Development Journey</a></li>
          <li><a href="#features">Features & Functionalities</a></li>
          <li><a href="#best-practices">Best Practices</a></li>
          <li><a href="#timeline">Development Timeline</a></li>
        </ul>
      </div>
      
      <div class="section" id="file-analysis">
        <div class="collapsible active">
          <div class="collapsible-header">📁 FILE ANALYSIS & DEPENDENCIES</div>
          <div class="collapsible-content">
            <ul>
              <li><span class="lead">Purpose:</span> Identify each file's role, interconnections, dependencies, and configuration.</li>
            </ul>
            <h3>📂 Core Application Files</h3>
            <ul>
              <li><b>Basic+Mediapose_v2_IPCam.py</b>: Main Windows version, multi-guard face/pose detection, GUI, logging, alerting. Loads <code>config.json</code> and manages all core logic.</li>
              <li><b>Basic+Mediapose_v2_IPCam_CUDA.ipynb</b>: Jupyter notebook, CUDA-optimized for Ubuntu/NVIDIA GPU. Adds GPU acceleration for face/pose detection, array ops, and image processing.</li>
              <li><b>config.json</b>: Central configuration (detection thresholds, alert intervals, performance, logging, storage paths, GPU settings).</li>
              <li><b>logs/events.csv</b>: CSV log of all detection and alert events (timestamp, name, action, status, image, confidence).</li>
              <li><b>logs/session.log</b>: Rotating log file for runtime warnings, errors, and system events.</li>
              <li><b>guard_profiles/</b>: Stores face images for each guard (multi-angle support).</li>
              <li><b>alert_snapshots/</b>: Alert-triggered screenshots (timestamped, per-guard/fugitive).</li>
              <li><b>capture_snapshots/</b>: Manual or automatic snapshots of detected faces.</li>
              <li><b>audio_files/</b>: Siren and alert sounds (e.g., <code>siren.mp3</code>).</li>
            </ul>
            <h3>📚 Documentation & Scripts</h3>
            <ul>
              <li><b>README_CUDA_SETUP.md</b>: Step-by-step Ubuntu/CUDA setup, driver and library install, Python env, troubleshooting.</li>
              <li><b>CUDA_MIGRATION_GUIDE.md</b>: Migration steps, code changes, config differences, performance benchmarks.</li>
              <li><b>FILES_SUMMARY.md</b>: Overview of all files, directory structure, usage workflow, dependencies, and backup/restore instructions.</li>
              <li><b>IMPROVEMENTS_CHANGELOG.md</b>: Changelog of major improvements (multi-guard detection, UI refactor, performance).</li>
              <li><b>COMPLETE_PROJECT_SUMMARY.md</b>: Executive summary of refactoring, feature enhancements, and requirements compliance.</li>
              <li><b>PHASE_4_COMPLETION_SUMMARY.md</b>: Final report for Phase 4 (parallel processing, control panel, QA, documentation).</li>
              <li><b>setup_cuda_ubuntu.sh</b>: Bash script for automated CUDA environment setup.</li>
            </ul>
            <h3>🔗 DEPENDENCIES & FRAMEWORKS</h3>
            <ul>
              <li><span class="lead">Python 3.11+</span> (Windows & Ubuntu)</li>
              <li><span class="lead">OpenCV</span> (with CUDA support on Ubuntu)</li>
              <li><span class="lead">MediaPipe</span> (pose detection, GPU delegate on Ubuntu)</li>
              <li><span class="lead">face_recognition</span> (dlib backend, CUDA on Ubuntu)</li>
              <li><span class="lead">TensorFlow 2.15</span> (GPU-enabled, for pose/NN ops)</li>
              <li><span class="lead">CuPy</span> (GPU array ops, Ubuntu only)</li>
              <li><span class="lead">customtkinter</span> (modern GUI)</li>
              <li><span class="lead">pygame, pydub</span> (audio alerts)</li>
              <li><span class="lead">psutil</span> (system monitoring)</li>
            </ul>
            <h3>⚙️ CONFIGURATION PARAMETERS</h3>
            <ul>
              <li><span class="lead">Detection:</span> min_detection_confidence, min_tracking_confidence, face_recognition_tolerance, re_detect_interval</li>
              <li><span class="lead">Alert:</span> default_interval_seconds, alert_cooldown_seconds</li>
              <li><span class="lead">Performance:</span> gui_refresh_ms, pose_buffer_size, frame_skip_interval, enable_frame_skipping, min_buffer_for_classification, gpu_batch_size</li>
              <li><span class="lead">Logging:</span> log_directory, max_log_size_mb, auto_flush_interval</li>
              <li><span class="lead">Storage:</span> alert_snapshots_dir, snapshot_retention_days, guard_profiles_dir, capture_snapshots_dir, audio_files_dir</li>
              <li><span class="lead">GPU:</span> device_id, memory_fraction, allow_growth</li>
            </ul>
            <h3>🔄 INTERCONNECTIONS</h3>
            <ul>
              <li>All core scripts load <code>config.json</code> and use shared directories for logs, profiles, and snapshots.</li>
              <li>Event and session logs are written by both Windows and CUDA versions.</li>
              <li>Documentation files reference each other for navigation and integration steps.</li>
            </ul>
          </div>
        </div>
      </div>
      
      <div class="section" id="architecture">
        <div class="collapsible">
          <div class="collapsible-header">🏗️ ARCHITECTURE & WORKFLOW</div>
          <div class="collapsible-content">
            <ul>
              <li><span class="lead">Purpose:</span> Reconstruct system architecture, data flow, and module interactions.</li>
            </ul>
            <h3>📋 SYSTEM ARCHITECTURE</h3>
            <ul>
              <li><b>Frontend:</b> CustomTkinter GUI (dark theme, collapsible sidebar, live camera feed, controls, guard previews, status indicators).</li>
              <li><b>Backend:</b> Real-time video processing (OpenCV), face/pose detection (MediaPipe, face_recognition), multi-guard tracking, alert logic, logging.</li>
              <li><b>Data Layer:</b> File-based storage (profiles, logs, snapshots), config-driven parameters.</li>
              <li><b>Services:</b> Audio alert playback (pygame/pydub), threaded IP camera grabber, parallel processing (ThreadPoolExecutor in Phase 4).</li>
              <li><b>Integrations:</b> CUDA GPU acceleration (Ubuntu), TensorFlow, CuPy, dlib, OpenCV CUDA modules.</li>
            </ul>
            <h3>📊 DATA FLOW DIAGRAM</h3>
            <div class="diagram">
[User/Camera]
   │
   ▼
[OpenCV Frame Capture]
   │
   ▼
[Face Detection & Encoding] ← [Guard Profiles]
   │
   ▼
[Pose Detection (MediaPipe)]
   │
   ▼
[Multi-Guard Assignment & Tracking]
   │
   ├──► [GUI Overlay & Previews]
   ├──► [Alert System (Audio/Visual)]
   └──► [Event Logging (CSV, Snapshots)]
            </div>
            <h3>🔍 API CONTRACTS & EXECUTION PATHS</h3>
            <ul>
              <li><span class="lead">User Input:</span> Camera selection, guard management, action filters, alert settings via GUI.</li>
              <li><span class="lead">Processing:</span> Each frame is processed for faces, matched to guards, pose classified, and actions/alerts triggered as needed.</li>
              <li><span class="lead">Outputs:</span> GUI overlays, alert sounds, CSV logs, image snapshots.</li>
              <li><span class="lead">Parallelism:</span> Phase 4+ uses per-guard parallel processing for scalability (ThreadPoolExecutor).</li>
            </ul>
            <h3>🗺️ MODULE MAP</h3>
            <ul>
              <li><b>Face/Pose Detection:</b> <code>face_recognition</code>, <code>mediapipe</code>, <code>opencv</code></li>
              <li><b>Tracking/Assignment:</b> Cost matrix, greedy assignment for 1-to-1 face-to-guard mapping</li>
              <li><b>GUI:</b> CustomTkinter, PIL for image display, scrollable/collapsible sidebar</li>
              <li><b>Logging:</b> RotatingFileHandler, CSV writer, snapshot/image saving</li>
              <li><b>Alerting:</b> Audio playback (pygame/pydub), cooldown logic, event triggers</li>
              <li><b>CUDA Pipeline (Ubuntu):</b> CuPy, OpenCV CUDA, TensorFlow GPU, dlib CUDA</li>
            </ul>
          </div>
        </div>
      </div>
      
      <div class="section" id="development-journey">
        <div class="collapsible">
          <div class="collapsible-header">📈 DEVELOPMENT JOURNEY</div>
          <div class="collapsible-content">
            <ul>
              <li><span class="lead">Purpose:</span> Chronicle phases, design decisions, and improvements.</li>
            </ul>
            <h3>🎯 DEVELOPMENT PHASES</h3>
            <ol>
              <li><b>Initial Legacy Script:</b> Monolithic, sequential detection, many unused dependencies, no parallelism.</li>
              <li><b>Phase 1: Aggressive Cleanup</b> (COMPLETE_PROJECT_SUMMARY.md)
                <ul>
                  <li>Removed 516 lines of dead/broken code (14% reduction)</li>
                  <li>Eliminated unused ML frameworks (torch, sklearn, scikit-image)</li>
                  <li>Fixed attribute and import errors</li>
                </ul>
              </li>
              <li><b>Phase 2: Feature Enhancement</b>
                <ul>
                  <li>Added multi-guard thumbnail preview (scrollable, color-coded, error handling)</li>
                  <li>UI improvements for guard management and camera controls</li>
                </ul>
              </li>
              <li><b>Phase 3: Parallel Multi-Guard Detection</b> (IMPROVEMENTS_CHANGELOG.md)
                <ul>
                  <li>Replaced sequential face-to-guard matching with cost matrix and greedy assignment</li>
                  <li>All faces and guards processed in one pass (1-to-1 mapping)</li>
                </ul>
              </li>
              <li><b>Phase 4: Production-Ready Refactor</b> (PHASE_4_COMPLETION_SUMMARY.md)
                <ul>
                  <li>Per-guard parallel processing (ThreadPoolExecutor)</li>
                  <li>Advanced control panel, real-time monitoring, error recovery, dynamic optimization</li>
                  <li>Comprehensive documentation and test suites</li>
                </ul>
              </li>
              <li><b>CUDA Migration (Ubuntu)</b>
                <ul>
                  <li>Ported to Jupyter notebook for GPU acceleration</li>
                  <li>Added dlib, OpenCV, MediaPipe, TensorFlow, CuPy GPU support</li>
                  <li>Setup scripts and guides for Ubuntu/CUDA deployment</li>
                </ul>
              </li>
            </ol>
            <h3>⚡ DESIGN DECISIONS & TRADE-OFFS</h3>
            <ul>
              <li><span class="lead">Removed:</span> All broken Phase 4 modules, PRO detection, ReID, and unused dependencies for maintainability and performance.</li>
              <li><span class="lead">Kept:</span> All core features (face/pose detection, multi-guard, alerting, logging, GUI).</li>
              <li><span class="lead">Parallelism:</span> Chose ThreadPoolExecutor for per-guard independence and scalability.</li>
              <li><span class="lead">GPU Acceleration:</span> CUDA migration for 3-4x performance boost, with minimal code changes (same API, config-driven).</li>
              <li><span class="lead">UI:</span> Collapsible sidebar to maximize camera feed area, scrollable controls for usability.</li>
            </ul>
            <h3>✅ TESTING & DEPLOYMENT</h3>
            <ul>
              <li>Syntax and code quality checks (py_compile, PEP8, docstrings, type hints)</li>
              <li>Manual and checklist-based feature testing (see COMPLETE_PROJECT_SUMMARY.md)</li>
              <li>Deployment scripts and backup/restore instructions (FILES_SUMMARY.md, README_CUDA_SETUP.md)</li>
            </ul>
            <h3>📝 REFACTORS & RELEASE NOTES</h3>
            <ul>
              <li>Major refactor in 2024-2025: 14% code reduction, 4x performance, 100% requirements compliance</li>
              <li>All changes and enhancements documented in markdown files (COMPLETE_PROJECT_SUMMARY.md, IMPROVEMENTS_CHANGELOG.md, PHASE_4_COMPLETION_SUMMARY.md)</li>
            </ul>
          </div>
        </div>
      </div>
      
      <div class="section" id="features">
        <div class="collapsible">
          <div class="collapsible-header">⚙️ APPLICATION FEATURES & FUNCTIONALITIES</div>
          <div class="collapsible-content">
            <ul>
              <li><span class="lead">Purpose:</span> List features, user-centric descriptions, technical notes, and maturity.</li>
            </ul>
            <h3>📋 FEATURE INVENTORY</h3>
            <table>
              <tr>
                <th>Feature</th><th>Description</th><th>Inputs</th><th>Outputs</th><th>Edge Cases</th><th>Dependencies</th><th>Maturity</th><th>Tests</th>
              </tr>
              <tr><td>Face Recognition</td><td>Detects and matches guard faces in live video</td><td>Camera frames, guard profiles</td><td>Face overlays, logs, alerts</td><td>Low light, occlusion, similar faces</td><td>face_recognition, dlib, OpenCV</td><td>Production</td><td>Manual+List</td></tr>
              <tr><td>Pose Detection & Classification</td><td>Classifies guard actions (Hands Up, Sit, Stand, etc.)</td><td>Camera frames</td><td>Action overlays, logs, alerts</td><td>Partial occlusion, fast movement</td><td>MediaPipe, TensorFlow</td><td>Production</td><td>Manual+List</td></tr>
              <tr><td>Multi-Guard Tracking</td><td>Tracks multiple guards in parallel, overlays, and logs</td><td>Camera frames, guard selection</td><td>Multi-box overlays, logs</td><td>Guards close together, similar faces</td><td>OpenCV, custom logic</td><td>Production</td><td>Manual+List</td></tr>
              <tr><td>Fugitive Mode</td><td>Single-person search and alert</td><td>Target face image</td><td>Alert, log, snapshot</td><td>Low confidence, false positives</td><td>face_recognition</td><td>Production</td><td>Manual</td></tr>
              <tr><td>GUI & Controls</td><td>Modern interface, sidebar, previews, controls</td><td>User input</td><td>Live feed, controls, status</td><td>Window resize, many guards</td><td>customtkinter, PIL</td><td>Production</td><td>Manual</td></tr>
              <tr><td>Alert System</td><td>Sound and visual alerts on detection</td><td>Detection events</td><td>Audio, overlays, logs</td><td>Audio device missing, repeated triggers</td><td>pygame, pydub</td><td>Production</td><td>Manual</td></tr>
              <tr><td>Data Management</td><td>Profiles, logs, snapshots, config</td><td>File I/O</td><td>CSV, images, config</td><td>Disk full, file corruption</td><td>Python stdlib</td><td>Production</td><td>Manual</td></tr>
              <tr><td>GPU Acceleration (Ubuntu)</td><td>All detection and processing on GPU</td><td>Camera frames</td><td>Faster overlays, logs</td><td>GPU OOM, driver issues</td><td>CuPy, TensorFlow, OpenCV CUDA</td><td>Production</td><td>Manual</td></tr>
            </table>
            <h3>💬 FEATURE NOTES</h3>
            <ul>
              <li><span class="lead">All features are production-ready and validated via manual and checklist-based testing.</span></li>
              <li>Removed features: Phase 4 framework, PRO detection, ReID, and unused dependencies (see <b>COMPLETE_PROJECT_SUMMARY.md</b>).</li>
              <li>Known limitations: Single camera feed, basic pose set, CSV logging (no DB), horizontal-only thumbnail scrolling.</li>
              <li>Suggested enhancements: Multi-camera, DB backend, web interface, SMS/email alerts, right-click menus, confidence overlays.</li>
            </ul>
          </div>
        </div>
      </div>
      
      <div class="section" id="best-practices">
        <div class="collapsible">
          <div class="collapsible-header">💡 BEST PRACTICES & RECOMMENDATIONS</div>
          <div class="collapsible-content">
            <ul>
              <li><span class="lead">Purpose:</span> Recommend improvements for scalability, maintainability, and reproducibility.</li>
            </ul>
            <h3>📊 SCALABILITY & MAINTAINABILITY</h3>
            <ul>
              <li>Adopt <b>modular code structure</b>: Separate detection, tracking, GUI, and logging into distinct modules.</li>
              <li>Use <b>config-driven parameters</b> for all thresholds, paths, and performance settings.</li>
              <li>Implement <b>unit and integration tests</b> for all core modules (see PHASE_4_COMPLETION_SUMMARY.md for test suite examples).</li>
              <li>Leverage <b>parallel processing</b> (ThreadPoolExecutor) for per-guard independence and scalability.</li>
              <li>For large deployments, consider <b>database-backed logging</b> and <b>web-based monitoring</b>.</li>
            </ul>
            <h3>📄 FOLDER STRUCTURE & NAMING</h3>
            <ul>
              <li>Follow the structure in <b>FILES_SUMMARY.md</b> and <b>README_CUDA_SETUP.md</b> for clarity and reproducibility.</li>
              <li>Use <b>snake_case</b> for Python files, <b>UPPERCASE</b> for config and docs, and <b>kebab-case</b> for scripts.</li>
              <li>Keep <b>all logs, profiles, and snapshots</b> in dedicated subfolders.</li>
            </ul>
            <h3>✔️ CODE STANDARDS</h3>
            <ul>
              <li>PEP8 compliance, 100% type hints, and docstrings (see PHASE_4_COMPLETION_SUMMARY.md).</li>
              <li>Rotating logs and error handling for robustness.</li>
              <li>Safe logging (ASCII sanitization) for cross-platform compatibility.</li>
            </ul>
            <h3>🚀 CI/CD & DEPLOYMENT</h3>
            <ul>
              <li>Automate environment setup with scripts (see <b>setup_cuda_ubuntu.sh</b>).</li>
              <li>Document all dependencies and version constraints in <b>README_CUDA_SETUP.md</b>.</li>
              <li>Backup and restore instructions for all critical files (see <b>FILES_SUMMARY.md</b>).</li>
            </ul>
            <h3>⚠️ RISKS & OPTIMIZATION OPPORTUNITIES</h3>
            <ul>
              <li><span class="lead">Risks:</span> GPU OOM, driver/library mismatches, file corruption, alert spam, UI scaling issues.</li>
              <li><span class="lead">Opportunities:</span> Batch processing, memory pooling, multi-GPU support, web dashboard, DB logging, cloud deployment.</li>
              <li><span class="lead">Missing pieces:</span> Automated test coverage reports, vertical thumbnail pagination, multi-camera support.</li>
            </ul>
            <div class="assumption">Assumptions: No evidence of automated CI/CD or database logging in current files. All claims above are based on explicit documentation and code comments.</div>
          </div>
        </div>
      </div>
      
      <div class="section" id="timeline">
        <div class="collapsible">
          <div class="collapsible-header">⏱️ DEVELOPMENT TIMELINE</div>
          <div class="collapsible-content">
            <div class="timeline">
              <div class="timeline-entry">
                <span class="timeline-date">2023</span> – Initial legacy script, monolithic, sequential detection, many unused dependencies.
              </div>
              <div class="timeline-entry">
                <span class="timeline-date">Early 2024</span> – <b>Phase 1:</b> Aggressive cleanup, dead code and dependency removal, bug fixes.
              </div>
              <div class="timeline-entry">
                <span class="timeline-date">Mid 2024</span> – <b>Phase 2:</b> Multi-guard preview enhancement, UI improvements.
              </div>
              <div class="timeline-entry">
                <span class="timeline-date">Late 2024</span> – <b>Phase 3:</b> Parallel multi-guard detection, cost matrix assignment, UI refactor (collapsible sidebar).
              </div>
              <div class="timeline-entry">
                <span class="timeline-date">Late 2024</span> – <b>Phase 4:</b> Production-ready refactor, per-guard parallelism, advanced control panel, QA, documentation.
              </div>
              <div class="timeline-entry">
                <span class="timeline-date">Dec 2025</span> – <b>CUDA Migration:</b> Ubuntu/Jupyter notebook, GPU acceleration, setup scripts, 4x performance, production deployment.
              </div>
            </div>
            <p style="margin-top: 2em;"><b>All statements above are tied to explicit evidence from the provided files and documentation.</b></p>
          </div>
        </div>
      </div>
    </div>
  </div>
</body>
</html>
'''))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <title>🔒 PoseGuard Elite Documentation Portal</title>
#   <style>
#     * { margin: 0; padding: 0; box-sizing: border-box; }
#     :root { --primary: #667eea; --secondary: #764ba2; --accent: #00d4ff; --dark: #0a0e27; }
#     body {
#       font-family: 'Inter', 'Segoe UI', sans-serif;
#       background: linear-gradient(-45deg, #667eea 0%, #764ba2 25%, #00d4ff 50%, #667eea 75%, #764ba2 100%);
#       background-size: 400% 400%;
#       animation: gradient-shift 15s ease infinite;
#       min-height: 100vh;
#       color: #e0e0e0;
#       padding: 0;
#       overflow-x: hidden;
#       position: relative;
#     }
#     body::before {
#       content: '';
#       position: fixed;
#       top: 0;
#       left: 0;
#       width: 100%;
#       height: 100%;
#       background: radial-gradient(ellipse at 20% 50%, rgba(102, 126, 234, 0.1) 0%, transparent 50%),
# ...
